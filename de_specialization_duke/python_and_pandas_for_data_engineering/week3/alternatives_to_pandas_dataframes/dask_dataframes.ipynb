# %% [markdown]
# # Dask

# %%
import pandas as pd
import random

# %%
leng = 1_000_000
data = {
    'a': (random.randint(0, 100) for _ in range(leng)),
    'b': (random.randint(2, 200) for _ in range(leng))
}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#     a    b
# 0  49   26
# 1   3   94
# 2  56  109
# 3  18  133
# 4  57  174

# %%
df.std()
# Out:
# a    29.132824
# b    57.414267
# dtype: float64

# %%
import dask.dataframe as dd

# %%
ddf = dd.from_pandas(df, npartitions=3)

# %%
ddf
# Out:
# Dask DataFrame Structure:
#                    a      b
# npartitions=3
# 0              int64  int64
# 333334           ...    ...
# 666667           ...    ...
# 999999           ...    ...
# Dask Name: from_pandas, 1 graph layer

# %%
ddf.std()
# Out:
# Dask Series Structure:
# npartitions=1
# a    float64
# b        ...
# dtype: float64
# Dask Name: astype, 8 graph layers

# %%
ddf.std().compute()
# Out:
# a    29.132824
# b    57.414267
# dtype: float64

# %%
result = ddf.a.sum() - ddf.b.sum()
result
# Out:
# dd.Scalar<sub-5a7..., dtype=int64>

# %%
result.compute()
# Out:
# -50986804

# %%
result.dask
# Out:
# HighLevelGraph with 8 layers.
# ...
#  0. from_pandas-286294f78705759630afaf3f4f3264ea
#  1. getitem-055a46673cff7d7b161141d702b632f5
#  2. series-sum-chunk-b87aacba0d78c967f8f96c4cb6d3c806-60f0d9fd7d651846152251cfd6978f42
#  3. series-sum-agg-b87aacba0d78c967f8f96c4cb6d3c806
#  4. getitem-7d456156f4209b24da3566feefdc0660
#  5. series-sum-chunk-0fd6712c63e7d10248e347d8445f6b67-e3e2dd8e55eb36167a1e24f2f12a9f5a
#  6. series-sum-agg-0fd6712c63e7d10248e347d8445f6b67
#  7. sub-5a75deb1ae47850d5d9cd5509b0988a3

# %%
result.visualize()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Max\work\jd\data_enginieering_zoomcamp\.env\Lib\site-packages\graphviz\backend\execute.py:76, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      75         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 76     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      77 else:
#
# File c:\Users\Max\work\jd\data_enginieering_zoomcamp\.env\Lib\site-packages\graphviz\backend\execute.py:96, in _run_input_lines(cmd, input_lines, kwargs)
#      95 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 96     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#      98     stdin_write = popen.stdin.write
#
# ...
